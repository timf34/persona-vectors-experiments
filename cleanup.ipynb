# %%
import os
# Truncate the heapsnapshot file to free disk space
path = "/home/claude-user/52feb588-8c4c-486b-8c90-2db5dbb3adfd.heapsnapshot"
with open(path, 'w') as f:
    pass
print(f"Truncated {path}")
print(f"File size now: {os.path.getsize(path)} bytes")
